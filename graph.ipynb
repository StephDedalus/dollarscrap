# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.dates as mdates

# %%
df = pd.read_excel('well.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5882 entries, 0 to 5881
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5882 non-null   object
#  1   Count   5882 non-null   int64
#  2   0       5882 non-null   int64
#  3   ER      5882 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 183.9+ KB

# %%
df.drop(0, axis=1, inplace=True)

# %%
import pylab
import matplotlib.ticker

# %%
sns.lineplot(data=df, x='Date', y='ER')
#formatter = matplotlib.ticker.NullFormatter()
#fig.xaxis.set_major_formatter (formatter)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ER'>

# %%
sns.barplot(x='Date', y='ER', data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ER'>
